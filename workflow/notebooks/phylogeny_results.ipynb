# %% [markdown]
# # Phylogeny results
#
# Baby 1 family, Bifido isolates

# %% [markdown]
# ## preamble

# %%
import os
import re

import toytree
import toyplot.pdf
import toyplot.png

# Matplotlib config
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib import font_manager

for font_file in font_manager.findSystemFonts(
    fontpaths=f'{os.environ['GROUP_HOME']}/fonts'
):
    font_manager.fontManager.addfont(font_file)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'

# %% [markdown]
# ## results

# %%
tree_file = '/raven/u/thosi/dev/tmp/bifido_v01_tree.raxml.bestTreeCollapsed'
tree = toytree.tree(tree_file)

# %%
canvas, axes, mark = tree.draw(
    tree_style='c',
    layout='r',
    edge_type='p',
    scale_bar=True,
    tip_labels_align=True,
    # tip_labels=tip_names,
    # tip_labels_colors=tip_labels_colors,
    tip_labels_style={'font-size': 12},
    node_sizes=10, 
    node_labels=False,
    node_mask=False, 
    width=600,
    height=1500,
)
canvas.style['background-color'] = 'white'
# toyplot.html.render(canvas, "/u/thosi/dev/tmp/combined-dp5-subset.html")
# Out:
# <div class="toyplot" id="tff146ed147ae4d62a945e47fe1d4940d" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="600.0px" height="1500.0px" viewBox="0 0 600.0 1500.0" preserveAspectRatio="xMidYMid meet" style="background-color:white;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb3c6346521e049bbb3039b640ab96d0f"><g class="toyplot-coordinates-Cartesian" id="t65cfb9a68f684b5ab7f963ef9340cdb0"><clipPath id="tfe4d9c3bda95439c864c7b345c9d2b96"><rect x="35.0" y="35.0" width="530.0" height="1430.0"></rect></clipPath><g clip-path="url(#tfe4d9c3bda95439c864c7b345c9d2b96)"><g class="toytree-mark-Toytree" id="t51fd1a923acf4357b7e54cb115e7ac68"><g class="toytree-Edges" style="stroke:rgb(
# ...
